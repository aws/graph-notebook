# %% [markdown]
# # Environment set up

# %%
# the endpoint generated by the cloudformation stack for neptune
endpoint = 'to be copied from CF'

# %%
import neptune_ml_utils as neptune_ml
neptune_ml.check_ml_enabled()
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# This Neptune cluster is configured to use Neptune ML

# %%
from gremlin_python import statics
from gremlin_python.structure.graph import Graph
from gremlin_python.process.graph_traversal import __
from gremlin_python.process.strategies import *
from gremlin_python.driver.driver_remote_connection import DriverRemoteConnection
from gremlin_python.driver.aiohttp.transport import AiohttpTransport
from gremlin_python.process.traversal import *
from gremlin_python.process.graph_traversal import id_
import os

# %%
s3_bucket_uri="s3://telcograph"

# %% [markdown]
# # Prepare the PoC for the Transductive mode

# %% [markdown]
# - drop some edges : Drop some links between some existing users and Cells to predict them with the transductive mode training.
# - training is already done and the model_transductive is available in the Endpoint
# - the transductive training take into account all users and cells properties as well as the user_live_cell properties.
# - for user_0 and cell_62000 we dropped ALL edges
# - for user_1500 and cell_56500 we dropped ALL edges
# - for user_4570 three edges user_live_cell_1678350, user_live_cell_734598, user_live_cell_487137

# %% [markdown]
# ### Select users to drop their user_live_cell edges

# %%
# %%gremlin
# g.V()
# .hasId("user_0")
# .outE()
# .hasLabel("user_live_cell")
# .inV()
# .valueMap(true, "name")
# .groupCount()
# .unfold()
# .order()
# .by(values, desc)
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…

# %%
# %%gremlin
# g.V('user_0').outE()
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…

# %%
# %%gremlin
# g.V('user_0').bothE().where(otherV().hasId('cell_62000'))
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…
# <div>
#
#         <style>
#             #results-pre{
#                 overflow: scroll;
#                 font-size: 1em !important;
#                 font-family: "Courier New", Courier, monospace !important;
#             }
#         </style>
#
#     <pre id="results-pre">Query mode                  | query
# Request execution time (ms) | 18.51
# # of results                | 0
# Response size (bytes)       | 56
# </pre>
# </div>
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="dc7cd93d-a2b3-4ea8-9ad5-f8ba273b5327" class="display hover nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th>#</th>
#       <th>Result</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [];
#
#     // Define the dt_args
#     let dt_args = {"scrollX": true, "scrollY": "475px", "columnDefs": [{"width": "5%", "targets": 0}, {"visible": true, "targets": 0}, {"searchable": false, "targets": 0}, {"minWidth": "95%", "targets": 1}, {"className": "nowrap dt-left", "targets": "_all"}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-weight', 'bold');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": 0}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-family', 'monospace');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": "_all"}], "paging": true, "scrollCollapse": true, "lengthMenu": [[10, 25, 50, 100, -1], [10, 25, 50, 100, "All"]], "pageLength": 10, "order": []};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#dc7cd93d-a2b3-4ea8-9ad5-f8ba273b5327').DataTable(dt_args);
#     });
# </script>
# </div>

# %%
#%%gremlin
#g.V('user_0').bothE().where(otherV().hasId('cell_62000')).drop()

# %%
# %%gremlin
# g.V()
# .hasId("user_1500")
# .outE()
# .hasLabel("user_live_cell")
# .inV()
# .valueMap(true, "name")
# .groupCount()
# .unfold()
# .order()
# .by(values, desc)
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…
# <div>
#
#         <style>
#             #results-pre{
#                 overflow: scroll;
#                 font-size: 1em !important;
#                 font-family: "Courier New", Courier, monospace !important;
#             }
#         </style>
#
#     <pre id="results-pre">Query mode                  | query
# Request execution time (ms) | 28.33
# # of results                | 67
# Response size (bytes)       | 696
# </pre>
# </div>
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="5d5a9489-5efc-4f63-8e71-6af5e6810f97" class="display hover nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th>#</th>
#       <th>Result</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[1, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_18500&#39;}: 6}"], [2, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_32500&#39;}: 6}"], [3, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_1500&#39;}: 6}"], [4, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_63500&#39;}: 6}"], [5, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_25500&#39;}: 6}"], [6, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_66500&#39;}: 5}"], [7, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_28500&#39;}: 5}"], [8, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_49500&#39;}: 5}"], [9, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_31500&#39;}: 5}"], [10, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_14500&#39;}: 5}"], [11, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_35500&#39;}: 5}"], [12, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_10500&#39;}: 5}"], [13, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_6500&#39;}: 5}"], [14, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_62500&#39;}: 5}"], [15, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_39500&#39;}: 5}"], [16, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_51500&#39;}: 5}"], [17, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_24500&#39;}: 5}"], [18, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_41500&#39;}: 5}"], [19, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_45500&#39;}: 5}"], [20, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_20500&#39;}: 5}"], [21, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_3500&#39;}: 5}"], [22, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_7500&#39;}: 5}"], [23, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_42500&#39;}: 5}"], [24, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_65500&#39;}: 5}"], [25, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_27500&#39;}: 5}"], [26, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_55500&#39;}: 5}"], [27, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_61500&#39;}: 5}"], [28, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_36500&#39;}: 5}"], [29, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_13500&#39;}: 5}"], [30, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_59500&#39;}: 5}"], [31, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_17500&#39;}: 5}"], [32, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_52500&#39;}: 5}"], [33, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_46500&#39;}: 5}"], [34, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_23500&#39;}: 5}"], [35, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_4500&#39;}: 5}"], [36, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_8500&#39;}: 5}"], [37, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_64500&#39;}: 5}"], [38, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_54500&#39;}: 5}"], [39, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_12500&#39;}: 5}"], [40, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_33500&#39;}: 5}"], [41, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_60500&#39;}: 5}"], [42, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_58500&#39;}: 5}"], [43, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_37500&#39;}: 5}"], [44, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_53500&#39;}: 5}"], [45, "{{&lt;T.label: 4&gt;: &#39;cell ...
#
#     // Define the dt_args
#     let dt_args = {"scrollX": true, "scrollY": "475px", "columnDefs": [{"width": "5%", "targets": 0}, {"visible": true, "targets": 0}, {"searchable": false, "targets": 0}, {"minWidth": "95%", "targets": 1}, {"className": "nowrap dt-left", "targets": "_all"}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-weight', 'bold');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": 0}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-family', 'monospace');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": "_all"}], "paging": true, "scrollCollapse": true, "lengthMenu": [[10, 25, 50, 100, -1], [10, 25, 50, 100, "All"]], "pageLength": 10, "order": []};
#     dt_args["

# %%
# %%gremlin
# g.V('user_1500').bothE().where(otherV().hasId('cell_56500'))
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…
# <div>
#
#         <style>
#             #results-pre{
#                 overflow: scroll;
#                 font-size: 1em !important;
#                 font-family: "Courier New", Courier, monospace !important;
#             }
#         </style>
#
#     <pre id="results-pre">Query mode                  | query
# Request execution time (ms) | 20.23
# # of results                | 0
# Response size (bytes)       | 56
# </pre>
# </div>
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="e51432a1-a7ab-45ec-98c7-8fdf0006240f" class="display hover nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th>#</th>
#       <th>Result</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [];
#
#     // Define the dt_args
#     let dt_args = {"scrollX": true, "scrollY": "475px", "columnDefs": [{"width": "5%", "targets": 0}, {"visible": true, "targets": 0}, {"searchable": false, "targets": 0}, {"minWidth": "95%", "targets": 1}, {"className": "nowrap dt-left", "targets": "_all"}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-weight', 'bold');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": 0}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-family', 'monospace');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": "_all"}], "paging": true, "scrollCollapse": true, "lengthMenu": [[10, 25, 50, 100, -1], [10, 25, 50, 100, "All"]], "pageLength": 10, "order": []};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#e51432a1-a7ab-45ec-98c7-8fdf0006240f').DataTable(dt_args);
#     });
# </script>
# </div>

# %%
# %%gremlin
# g.V()
# .hasId("user_1500")
# .outE()
# .hasLabel("user_live_cell")
# .inV()
# .valueMap(true, "name")
# .groupCount()
# .unfold()
# .order()
# .by(values, desc)
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…
# <div>
#
#         <style>
#             #results-pre{
#                 overflow: scroll;
#                 font-size: 1em !important;
#                 font-family: "Courier New", Courier, monospace !important;
#             }
#         </style>
#
#     <pre id="results-pre">Query mode                  | query
# Request execution time (ms) | 30.6
# # of results                | 67
# Response size (bytes)       | 696
# </pre>
# </div>
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="082bca8d-e93f-4319-99f4-e97f0e1be569" class="display hover nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th>#</th>
#       <th>Result</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[1, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_18500&#39;}: 6}"], [2, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_32500&#39;}: 6}"], [3, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_1500&#39;}: 6}"], [4, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_63500&#39;}: 6}"], [5, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_25500&#39;}: 6}"], [6, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_66500&#39;}: 5}"], [7, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_28500&#39;}: 5}"], [8, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_49500&#39;}: 5}"], [9, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_31500&#39;}: 5}"], [10, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_14500&#39;}: 5}"], [11, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_35500&#39;}: 5}"], [12, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_10500&#39;}: 5}"], [13, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_6500&#39;}: 5}"], [14, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_62500&#39;}: 5}"], [15, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_39500&#39;}: 5}"], [16, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_51500&#39;}: 5}"], [17, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_24500&#39;}: 5}"], [18, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_41500&#39;}: 5}"], [19, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_45500&#39;}: 5}"], [20, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_20500&#39;}: 5}"], [21, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_3500&#39;}: 5}"], [22, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_7500&#39;}: 5}"], [23, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_42500&#39;}: 5}"], [24, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_65500&#39;}: 5}"], [25, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_27500&#39;}: 5}"], [26, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_55500&#39;}: 5}"], [27, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_61500&#39;}: 5}"], [28, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_36500&#39;}: 5}"], [29, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_13500&#39;}: 5}"], [30, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_59500&#39;}: 5}"], [31, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_17500&#39;}: 5}"], [32, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_52500&#39;}: 5}"], [33, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_46500&#39;}: 5}"], [34, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_23500&#39;}: 5}"], [35, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_4500&#39;}: 5}"], [36, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_8500&#39;}: 5}"], [37, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_64500&#39;}: 5}"], [38, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_54500&#39;}: 5}"], [39, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_12500&#39;}: 5}"], [40, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_33500&#39;}: 5}"], [41, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_60500&#39;}: 5}"], [42, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_58500&#39;}: 5}"], [43, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_37500&#39;}: 5}"], [44, "{{&lt;T.label: 4&gt;: &#39;cell&#39;, &lt;T.id: 1&gt;: &#39;cell_53500&#39;}: 5}"], [45, "{{&lt;T.label: 4&gt;: &#39;cell ...
#
#     // Define the dt_args
#     let dt_args = {"scrollX": true, "scrollY": "475px", "columnDefs": [{"width": "5%", "targets": 0}, {"visible": true, "targets": 0}, {"searchable": false, "targets": 0}, {"minWidth": "95%", "targets": 1}, {"className": "nowrap dt-left", "targets": "_all"}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-weight', 'bold');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": 0}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-family', 'monospace');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": "_all"}], "paging": true, "scrollCollapse": true, "lengthMenu": [[10, 25, 50, 100, -1], [10, 25, 50, 100, "All"]], "pageLength": 10, "order": []};
#     dt_args["

# %%
# %%gremlin
# g.V('user_4570').bothE().where(otherV().hasId('cell_10570'))
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…
# <div>
#
#         <style>
#             #results-pre{
#                 overflow: scroll;
#                 font-size: 1em !important;
#                 font-family: "Courier New", Courier, monospace !important;
#             }
#         </style>
#
#     <pre id="results-pre">Query mode                  | query
# Request execution time (ms) | 20.28
# # of results                | 3
# Response size (bytes)       | 88
# </pre>
# </div>
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="68ce728e-a6ee-4a8f-9d2c-14a9fdc93da9" class="display hover nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th>#</th>
#       <th>Result</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[1, "e[user_live_cell_487137][user_4570-user_live_cell-&gt;cell_10570]"], [2, "e[user_live_cell_326296][user_4570-user_live_cell-&gt;cell_10570]"], [3, "e[user_live_cell_1654133][user_4570-user_live_cell-&gt;cell_10570]"]];
#
#     // Define the dt_args
#     let dt_args = {"scrollX": true, "scrollY": "475px", "columnDefs": [{"width": "5%", "targets": 0}, {"visible": true, "targets": 0}, {"searchable": false, "targets": 0}, {"minWidth": "95%", "targets": 1}, {"className": "nowrap dt-left", "targets": "_all"}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-weight', 'bold');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": 0}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-family', 'monospace');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": "_all"}], "paging": true, "scrollCollapse": true, "lengthMenu": [[10, 25, 50, 100, -1], [10, 25, 50, 100, "All"]], "pageLength": 10, "order": []};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#68ce728e-a6ee-4a8f-9d2c-14a9fdc93da9').DataTable(dt_args);
#     });
# </script>
# </div>

# %%
# %%gremlin
# g.V('user_4570').outE('user_live_cell').hasId('user_live_cell_734598').drop()
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…
# <div>
#
#         <style>
#             #results-pre{
#                 overflow: scroll;
#                 font-size: 1em !important;
#                 font-family: "Courier New", Courier, monospace !important;
#             }
#         </style>
#
#     <pre id="results-pre">Query mode                  | query
# Request execution time (ms) | 19.68
# # of results                | 0
# Response size (bytes)       | 56
# </pre>
# </div>
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="14aca6db-2b7e-4606-8bca-09dc0ebb70b7" class="display hover nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th>#</th>
#       <th>Result</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [];
#
#     // Define the dt_args
#     let dt_args = {"scrollX": true, "scrollY": "475px", "columnDefs": [{"width": "5%", "targets": 0}, {"visible": true, "targets": 0}, {"searchable": false, "targets": 0}, {"minWidth": "95%", "targets": 1}, {"className": "nowrap dt-left", "targets": "_all"}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-weight', 'bold');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": 0}, {"createdCell":
#             function (td, cellData, rowData, row, col) {
#                 $(td).css('font-family', 'monospace');
#                 $(td).css('font-size', '12px');
#             }
#             , "targets": "_all"}], "paging": true, "scrollCollapse": true, "lengthMenu": [[10, 25, 50, 100, -1], [10, 25, 50, 100, "All"]], "pageLength": 10, "order": []};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#14aca6db-2b7e-4606-8bca-09dc0ebb70b7').DataTable(dt_args);
#     });
# </script>
# </div>

# %%
#%%gremlin
#g.V('user_4570').outE('user_live_cell').hasId('user_live_cell_1678350').drop()

# %%
# %%gremlin
# g.V('user_4570').bothE().where(otherV().hasId('cell_10570'))
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…

# %% [markdown]
# # Launch the export
# ## Frame the link prediction task in the export_param

# %%
export_params={ 
"command": "export-pg", 
"params": { "endpoint": neptune_ml.get_host(),
            "profile": "neptune_ml",
            "useIamAuth": neptune_ml.get_iam(),
            "cloneCluster": False,
            "nodeLabels": ["user", "cell"],
            "edgeLabels": ["user_live_cell"]
            }, 
"outputS3Path": f'{s3_bucket_uri}/neptune-export',
"additionalParams": {
        "neptune_ml": {
          "version": "v2.0",
          "targets": [
            {
                "edge": ["user", "user_live_cell", "cell"],
                "type" : "link_prediction",
                "split_rate": [0.8, 0.1, 0.1]
            }
         ]
        }
      },
"jobSize": "xlarge"}
export_params
# Out:
# {'command': 'export-pg',
#  'params': {'endpoint': 'cluster.cluster-c2wgvyuhzgmx.eu-west-1.neptune.amazonaws.com',
#   'profile': 'neptune_ml',
#   'useIamAuth': False,
#   'cloneCluster': False,
#   'nodeLabels': ['user', 'cell'],
#   'edgeLabels': ['user_live_cell']},
#  'outputS3Path': 's3://telcograph/neptune-export',
#  'additionalParams': {'neptune_ml': {'version': 'v2.0',
#    'targets': [{'edge': ['user', 'user_live_cell', 'cell'],
#      'type': 'link_prediction',
#      'split_rate': [0.8, 0.1, 0.1]}]}},
#  'jobSize': 'xlarge'}

# %%
# %%neptune_ml export start --export-url {neptune_ml.get_export_service_host()} --export-iam --wait --store-to export_results
# ${export_params}
# Out:
# Output()

# %%
# check the status
# %neptune_ml export status --export-url {neptune_ml.get_export_service_host()} --export-iam --job-id 4660f4dd-bcdf-4abe-949a-692ddd54f593
# Out:
# Output()
# Tab(children=(Output(layout=Layout(overflow='scroll')),), _titles={'0': 'Error'})

# %% [markdown]
# # Data processing/Preparation of graph data for Training

# %% [markdown]
# NB. Precise in export_param the S3 with the latest export to consider

# %%
# The training_job_name can be set to a unique value below, otherwise one will be auto generated
training_job_name=neptune_ml.get_training_job_name('link-prediction')

processing_params = f"""
--config-file-name training-data-configuration.json
--job-id {training_job_name} 
--instance-type ml.r5.16xlarge
--s3-input-uri s3://telcograph/neptune-export/20230518_072439
--s3-processed-uri {str(s3_bucket_uri)}/preloading """

# %%
# %neptune_ml dataprocessing start --wait --store-to processing_results {processing_params}
# Out:
# Output()
# Tab(children=(Output(layout=Layout(overflow='scroll')),), _titles={'0': 'Error'})

# %% [markdown]
# # Training

# %% [markdown]
# <div style="background-color:#eeeeee; padding:20px; text-align:left; border-radius:10px; margin-top:10px; margin-bottom:10px; "><b>Information</b>: Link prediction is a more computationally complex model than classification or regression </div>

# %% [markdown]
# ## Transductive Training steps

# %%
#check the Ids for training and processing jobs
training_job_name = "my-train-job-ept-hypmodv9"
training_job_name
# Out:
# 'my-train-job-ept-hypmodv9'

# %%
# !curl -s "https://cluster.cluster-c2wgvyuhzgmx.eu-west-1.neptune.amazonaws.com:8182/ml/dataprocessing/"
# Out:
# {"ids":["link-prediction-1690116689","link-prediction-1687117627","link-prediction-1684928671"]}

# %%
# !curl -s "https://cluster.cluster-c2wgvyuhzgmx.eu-west-1.neptune.amazonaws.com:8182/ml/dataprocessing/link-prediction-1684928671"
# Out:
# {"processingJob":{"name":"link-pre-preloading-2023-05-24-11-44-390000","arn":"arn:aws:sagemaker:eu-west-1:134846823987:processing-job/link-pre-preloading-2023-05-24-11-44-390000","status":"Completed","outputLocation":"s3://telcograph/preloading/link-pre-preloading-2023-05-24-11-44-390000/preloading-output"},"id":"link-prediction-1684928671","status":"Completed"}

# %%
training_params=f"""
--job-id {training_job_name}
--data-processing-id {training_job_name}
--instance-type ml.g4dn.16xlarge
--s3-output-uri {str(s3_bucket_uri)}/training
--max-hpo-number 1
--max-hpo-parallel 3 """

# %%
training_params

# %%
# %neptune_ml training start --wait --store-to training_results {training_params}
# Out:
# Output()

# %%
training_params
# Out:
# '\n--job-id my-train-job-ept-hypmodv9\n--data-processing-id my-train-job-ept-hypmodv9\n--instance-type ml.g4dn.16xlarge\n--s3-output-uri s3://telcograph/training\n--max-hpo-number 1\n--max-hpo-parallel 3 '

# %%
# %neptune_ml training status --job-id my-train-job-ept-hypmodv9
# Out:
# Output()

# %% [markdown]
# # Inference

# %% [markdown]
# ## Endpoint creation

# %%
endpoint_params=f"""
--id {training_job_name}
--model-training-job-id {training_job_name}"""
endpoint_params

# %%
# %neptune_ml endpoint create --wait --store-to endpoint_results {endpoint_params}

# %%
endpoint_transductive=endpoint_results['endpoint']['name']

# %%
endpoint_transductive ='my-train-2023-08-29-10-12-7520000-endpoint'

# %% [markdown]
# ### reminder
#
# - user_0 and cell_62000 / dropped ALL edges
#
# - user_1500 and cell_56500 / dropped ALL edges
#
# - user_4570 three edges of cell_10570

# %%
import boto3
import json
import time

def invoke_sagemaker_endpoint(endpoint_name, vertex_id, edge_type, head_node_type=None, tail_node_type=None, 
    exclude_flag='null', topk=10, response_format='application/json', region='eu-west-1'):
    if tail_node_type:
        input_data = {
            "version": "v1",
            "mode": "predict_tail",
            "data": {
                "globalParameters": {
                    'topk': topk,
                    'edgeType': edge_type,
                    'tailNodeType': tail_node_type,
                    'excludeFlag': exclude_flag
                },
                "edges": [
                    {
                        "headNodeId": vertex_id,
                    }
                ]
            }
        }
    else:
        input_data = {
            "version": "v1",
            "mode": "predict_head",
            "data": {
                "globalParameters": {
                    'topk': topk,
                    'edgeType': edge_type,
                    'headNodeType': head_node_type,
                    'excludeFlag': exclude_flag
                },
                "edges": [
                    {
                        "tailNodeId": vertex_id,
                    }
                ]
            }
        }
    sagemaker_runtime = boto3.client('sagemaker-runtime', region_name=region)
    payload = json.dumps(input_data)
    tic = time.time()
    response = sagemaker_runtime.invoke_endpoint(EndpointName=endpoint_name,
                                                 ContentType='application/json',
                                                 Accept=response_format,
                                                 Body=payload)
    duration = time.time() - tic
    print()
    output = json.loads(response['Body'].read().decode())["output"]
    for result in output["edges"][0]["mlResults"]:
        print(result['inferredValue'])
    print("Inference took {} milliseconds".format(duration*1000))

# %% [markdown]
# <img src="attachment:2a0d7696-5e11-42af-a56f-f7acc5d63572.png" alt="image.png" width="1000"/>

# %% [markdown]
# ## DEMO shows: how GNN predicts to which cells, given user will be connected or Predicting which users are going to connect to a given cell

# %% [markdown]
# <div style="background-color:#eeeeee; padding:20px; text-align:left; border-radius:10px; margin-top:10px; margin-bottom:10px; "><b>Experimentation1</b>: GNN is going to predict that user_0 is connected to cell_62000</div>

# %%
# %%gremlin
# g.with("Neptune#ml.endpoint","${endpoint_transductive}")
# .with("Neptune#ml.limit", 5)
# .V("cell_62000")
# .in("user_live_cell").with("Neptune#ml.prediction").hasLabel("user")
# Out:
# Keyboard interrupt detected.

# %% [markdown]
# <div style="background-color:#eeeeee; padding:20px; text-align:left; border-radius:10px; margin-top:10px; margin-bottom:10px; "><b>Experimentation2</b>: GNN is going to predict that user_1500 is connected to cell_56500</div>

# %%
# %%gremlin
# g.with("Neptune#ml.endpoint","${endpoint_transductive}")
# .with("Neptune#ml.limit",10)
# .V("cell_56500")
# .in("user_live_cell").with("Neptune#ml.prediction").hasLabel("user")
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…

# %% [markdown]
# <div style="background-color:#eeeeee; padding:20px; text-align:left; border-radius:10px; margin-top:10px; margin-bottom:10px; "><b>Experimentation3</b>: GNN is going to predict that user_1500 is connected to cell_63500</div>

# %%
# %%gremlin
# g.with("Neptune#ml.endpoint","${endpoint_transductive}")
# .with("Neptune#ml.limit",5)
# .V("user_1500")
# .out("user_live_cell").with("Neptune#ml.prediction").with("Neptune#ml.filterExistingEdges").hasLabel("cell")
# Out:
# Tab(children=(Output(layout=Layout(max_height='600px', max_width='940px', overflow='scroll')), Output(layout=L…

# %% [markdown]
# # end to end architecture for multi- scenario

# %% [markdown]
# <img src="attachment:f8b596d3-26cd-4127-aebb-132900d153db.png" alt="image.png" width="1000"/>

# %% [markdown]
# # Note on GNN evaluation
#
# - HITS@10 provides a measure of how often the model suggests the correct item within the top 10 recommendation
#
# - While MR gives an overall indication of how close the correct item is to the top of the list on average.
#
# - Sagemaker evaluate the model on the train and test set
#
# - Results on test set
#
#     * "HITS at top 1 (HITS@1)": 0.4010819758391616,
#     * "HITS at top 10 (HITS@10)": 0.9438622262173598,
#     * "HITS at top 3 (HITS@3)": 0.6301810418539388,
#     * "mean rank (MR)": 3.719502285632852,
